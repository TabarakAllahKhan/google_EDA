# %% [markdown]
# ## 1. About Arthour
#
# + **Project** : Exploratory Data Analysis using Google Play Store Data
# + **Author** : Tabarak Allah Khan alizai
# + **Contact** :
# [![Gmail Icon](https://img.shields.io/badge/Gmail-red?style=flat&logo=gmail&logoColor=white)](tabarakalizai861@gmail.com)
# [![LinkedIn Icon](https://img.shields.io/badge/LinkedIn-blue?style=flat&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/tabarakallahkhan/)
# [![GitHub Icon](https://img.shields.io/badge/GitHub-black?style=flat&logo=github&logoColor=white)](https://github.com/TabarakAllahKhan)
# [![Kaggle Icon](https://img.shields.io/badge/Kaggle-blue?style=flat&logo=kaggle&logoColor=white)](https://www.kaggle.com/tabarakalizai)

# %% [markdown]
# ## 2. About Data
#
# + Data: Google PlayStore Data
# + Data Age: The Data was collected in 2019
# + Data Set : [Link](https://www.kaggle.com/datasets/lava18/google-play-store-apps/data)
#
# ### 2.1 Task:
# We plan to perform an Exploratory Data Analysis (EDA) on the provided dataset. This analysis will inform the Data Wrangling procedures required for data cleaning and normalization. Throughout the coding phase, we will systematically document our observations. Finally, we will compile a summary of our findings and present the conclusions drawn from the analysis.
#
# ### 2.2.Objective:
# The primary aim of this project is to conduct a thorough analysis of the dataset to identify significant insights. The ultimate goal is to project and emphasize customer dynamics and demands to developers and other relevant stakeholders. This will assist in driving more business towards their upcoming applications.
#
# ### 2.3 Kernel Version
#
# + Python 3.12.8
#
# ### 2.4 Input Features In the Dataset:

# %% [markdown]
# | Column Name | Description | Data Type |
# |---|---|---|
# | **App** | Name of the App on the Google Playstore | Object |
# | **Category** | The Type of app like entertainment , Sport,For Adults | Object |
# | **Rating** | The Rating given to the app by the users | Float |
# | **Reviews** | The number of reviews given to the particular app | Object |
# | **Size** | The installation memory size of the app  | Object |
# | **Installs** | The Total number of installs of the app | Object |
# | **Type** | The type of app like paid or free | Object |
# | **Price** | The price of the app if it is free type it is 0 and if it is paid the price will be written | Object |
# | **Content Rating** | The content rating of the app | Object |
# | **Genres** | The Genres of the app (`Containes same entries as the Category column`) | Object |
# | **Current Ver** |  The current version of the app | Object |
# | **Android ver** | The minimum android version required to run the app | Object |

# %% [markdown]
# ## _3.0 Import Libraries_
#
# 1. Pandas : For data manipulation and analysis
# 2. Numpy : For numerical computations
# 3. Matplotlib : For data visualization
# 4. Seaborn : Statistical data visualization library.
# 5. ydata-profiling : For Automatic EDA.

# %%
import pandas as pd
import numpy as np
# Data Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## _4.0 Data Loading , Exploration & Wrangling_
# We will proceed as follows:
# #### 4.1 Load The csv file with pandas
#
# #### 4.2 Creating Dataframe and understand the data present inside the dataset
#
# #### 4.3 Dealing with the missing data and the incorrect records

# %%
# Load Dataset
df=pd.read_csv('googleplaystore.csv')

# %% [markdown]
# #### 4.4 Analysing & describing the dataset
#
# This code snippet enables a comprehensive view of your data by modifying a crucial display setting in Pandas. By configuring the option to display all columns, you can ensure that no essential information is missed when examining dataframes. Whether you are exploring data, performing analyses, or gaining a deeper understanding of your dataset, this straightforward adjustment can significantly enhance your workflow.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### _4.5 Get overview of the data_
# With just a single line of code we will get the views top 5 rows of the data. This is useful for getting an overview of the data.

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# ### _4.6 View the column names_

# %%
print(df.columns.values)
# Out:
# ['App' 'Category' 'Rating' 'Reviews' 'Size' 'Installs' 'Type' 'Price'
#  'Content Rating' 'Genres' 'Last Updated' 'Current Ver' 'Android Ver']

# %%
# hiding warnings for better visualization

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### _4.7 View the shape of the dataset_

# %%
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# The dataset has 10841 rows and 13 columns.

# %% [markdown]
# _Observation Set 1:_
#
# + Attribute Price , size and other attributes are not the numeric type , They are either string or other datatype that will be converted to numeric datatype
#
# _Column Names are:_
#
# ['App' 'Category' 'Rating' 'Reviews' 'Size' 'Installs' 'Type' 'Price'
#  'Content Rating' 'Genres' 'Last Updated' 'Current Ver' 'Android Ver'
#  'Install_Category']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### _4.8 Descriptive Statistics_

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# _Obeservation set 2:_
#
# + We have currently only 2 numeric attribute `Rating` & `Reviews` in the dataset. But that is not fully correct. We have to convert other attributes to the numeric type.

# %% [markdown]
# ### _4.9 Missing Values in the data_

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Rating            1474
# Current Ver          8
# Android Ver          2
# Category             1
# Type                 1
# Size                 0
# Reviews              0
# App                  0
# Installs             0
# Content Rating       0
# Price                0
# Last Updated         0
# Genres               0
# dtype: int64

# %% [markdown]
# ### _5.0 Exploratory Data Analysis and Visualization_

# %%
plt.rcParams['figure.figsize'] = (15,6)
sns.heatmap(df.isnull(),yticklabels = False, cbar = False , cmap = 'viridis')
plt.title("Missing null values")
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %% [markdown]
# **Fig -1:** *HeatMap Of the NullValues In the dataset*

# %%
# Missing values percentage

missing_percentage = (df.isnull().sum().sort_values(ascending = False)/len(df))*100
missing_percentage
# Out:
# Rating            13.596532
# Current Ver        0.073794
# Android Ver        0.018448
# Category           0.009224
# Type               0.009224
# Size               0.000000
# Reviews            0.000000
# App                0.000000
# Installs           0.000000
# Content Rating     0.000000
# Price              0.000000
# Last Updated       0.000000
# Genres             0.000000
# dtype: float64

# %% [markdown]
# ### 5.1 We will generate a graphical representation of the percentage of null values by plotting the data using an appropriate charting technique.

# %%
missing_percentage = missing_percentage[missing_percentage != 0] # Only the missing data
plt.rcParams['figure.figsize'] = (20,6)
missing_percentage.plot(kind = 'barh')
plt.title("Percentage of null values")
# Out:
# Text(0.5, 1.0, 'Percentage of null values')

# %% [markdown]
# **Fig -2:** *Histogram of percentage of Nullvalues*

# %% [markdown]
# Obeservation set 3:
#
# + The Size attribute have app size with the letter `M` and `K` which represent megabite and kilobite respectively.
# + Some values are written as **varies with device** , means it has no record of the app size.
# + The attribute having high percentage of null values is Rating

# %% [markdown]
# ### 5.3 _Finding values having M , k , varies with device_

# %%
# find the values having M in them

df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# np.int64(8830)

# %%
# find the values having k in them
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# np.int64(316)

# %%
# find the values having Varies with device in them
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# np.int64(1695)

# %%
len(df['Size'])
# Out:
# 10841

# %%
8830+316+1695
# Out:
# 10841

# %% [markdown]
# ### _5.4 Converting whole size column into bytes_

# %%
# lets define a function

def convert_size(size):
    if isinstance(size,str):
        if 'k' in size:
            return float(size.replace('k',"")) * 1024
        elif 'M' in size:
            return float(size.replace('M',"")) * 1024 * 1024
        elif 'Varies with device' in size:
            return np.nan
    return size

# %%
df['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
# 5                      5.6M
# 6                       19M
# 7                       29M
# 8                       33M
# 9                      3.1M
# 10                      28M
# 11                      12M
# 12                      20M
# 13                      21M
# 14                      37M
# 15                     2.7M
# 16                     5.5M
# 17                      17M
# 18                      39M
# 19                      31M
# 20                      14M
# 21                      12M
# 22                     4.2M
# 23                     7.0M
# 24                      23M
# 25                     6.0M
# 26                      25M
# 27                     6.1M
# 28                     4.6M
# 29                     4.2M
# 30                     9.2M
# 31                     5.2M
# 32                      11M
# ...

# %%
df['Size']=df['Size'].apply(convert_size)

# %%
df['Size']
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37               NaN
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42               NaN
# ...

# %% [markdown]
# ### _5.5 Renaming the Size Col_

# %%
df.rename(columns={'Size':'Size_in_bytes'},inplace=True)

df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %% [markdown]
# ### _5.6 Creating a new Size_in_MB col_

# %%
df['Size_in_Mb']=df['Size_in_bytes'].apply(lambda x: x/(1024*1024))

# %%
df['Size_in_Kb']=df['Size_in_bytes'].apply(lambda x: x/(1024))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %% [markdown]
# ## MileStone 1 : We have converted the size attribute into a float type removed the K and M and varies with device values . We have also added a new attribute called "size_in_mb" which is calculated by multiplying the size attribute by 1024 . This will help us to get the size in megabytes .

# %% [markdown]
# ### _5.7 Taking Care of Install Col_

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
df['Installs'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# As there are no null values in the Install Attribute only the thing we have to deal with is the plus sign `+` and the comma sign `,` and convert the datatype to int as it has not decimal point in the values

# %%
# if statment is written after because of lamda function structure
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+', ''))

# %%
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',', ''))

# %%
# converting all values to int 

df['Installs'] = df['Installs'].apply(lambda x: int(x))

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %% [markdown]
# ### _5.8 Dealing with `$` sign in the Price Col_

# %%
df['Price']=df['Price'].apply(lambda x: x.replace('$',''))

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# 0.99         148
# 2.99         129
# 1.99          73
# 4.99          72
# 3.99          63
# 1.49          46
# 5.99          30
# 2.49          26
# 9.99          21
# 6.99          13
# 399.99        12
# 14.99         11
# 4.49           9
# 29.99          7
# 3.49           7
# 7.99           7
# 24.99          7
# 5.49           6
# 19.99          6
# 6.49           5
# 8.99           5
# 12.99          5
# 11.99          5
# 10.00          3
# 1.00           3
# 16.99          3
# 2.00           3
# 17.99          2
# 10.99          2
# 9.00           2
# 79.99          2
# 7.49           2
# 3.95           2
# 33.99          2
# 1.70           2
# 13.99          2
# 8.49           2
# 39.99          2
# 1.50           1
# 25.99          1
# 74.99          1
# 15.99          1
# 3.88           1
# 1.76           1
# 3.02           1
# 400.00         1
# 4.84           1
# 2.50           1
# 1.59           1
# 1.61           1
# 4.77           1
# ...

# %%
# Now convert from Int type to float type

df['Price']=df['Price'].apply(lambda x: float(x))

# %%
print(f"Min price: {df['Price'].min()}")
print(f"Max price: {df['Price'].max()}")
print(f"Mean price: {df['Price'].mean()}")
# Out:
# Min price: 0.0
# Max price: 400.0
# Mean price: 1.0272733142699015

# %%
# Finding the missing value percentage in the dataset after feature engineering
round(df.isnull().sum()/len(df)*100,2).sort_values(ascending=False)
# Out:
# Size_in_bytes     15.64
# Size_in_Kb        15.64
# Size_in_Mb        15.64
# Rating            13.60
# Current Ver        0.07
# Android Ver        0.02
# Category           0.01
# Type               0.01
# Installs           0.00
# App                0.00
# Reviews            0.00
# Last Updated       0.00
# Genres             0.00
# Content Rating     0.00
# Price              0.00
# dtype: float64

# %%
# total missing values in the dataset
df.isnull().sum().sum()
# Out:
# np.int64(6571)

# %%
# plot missing values in the dataset after feature engineering
plt.rcParams['figure.figsize'] = (16,6)
sns.heatmap(df.isnull(),yticklabels = False, cbar = False , cmap = 'viridis')
# Out:
# <Axes: >

# %% [markdown]
# **Fig -3:** *HeatMap of missing values in the dataset after creating the new columns*

# %%
# make histogram of percentage of missing values in the dataset after feature engineering
plt.figure(figsize=(16,6))
# plot null values by their percentage in each column
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of missing values in each column')
# Out:
# Text(0.5, 1.0, 'Percentage of missing values in each column')

# %% [markdown]
# **Fig -4:** *This graph represents sales.*

# %% [markdown]
# ### _5.9 Creating Bins:_
# The following code creates bins for the data:

# %%
# creating bins for the Installs column and creating a new column Installs_category
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['no', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['Installs_category'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df['Installs_category'].value_counts() # check the value counts of the new column
# Out:
# Installs_category
# Low                   2162
# High                  2118
# Very High             2004
# More than moderate    1648
# Moderate              1531
# Top Notch              828
# Very low               535
# no                      15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 6)) # make figure size
missing_percentage[missing_percentage < 1].plot(kind='bar') # plot the null values by their percentage in each column
plt.xlabel('Columns') # add the x-axis labels
plt.ylabel('Percentage') # add the labels for y-axis
plt.title('Percentage of Missing Values in each Column without Rating column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column without Rating column')

# %% [markdown]
# **Fig -5:** *Percentage of missing values in each column without Rating column*

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False) # this will show the percentage of null values in each column
# Out:
# Size_in_bytes        15.635089
# Size_in_Kb           15.635089
# Size_in_Mb           15.635089
# Rating               13.596532
# Current Ver           0.073794
# Android Ver           0.018448
# Type                  0.009224
# Category              0.009224
# Price                 0.000000
# Installs              0.000000
# App                   0.000000
# Reviews               0.000000
# Last Updated          0.000000
# Genres                0.000000
# Content Rating        0.000000
# Installs_category     0.000000
# dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False) # this will show the number of null values in each column in descending order
# Out:
# Size_in_bytes        1695
# Size_in_Kb           1695
# Size_in_Mb           1695
# Rating               1474
# Current Ver             8
# Android Ver             2
# Type                    1
# Category                1
# Price                   0
# Installs                0
# App                     0
# Reviews                 0
# Last Updated            0
# Genres                  0
# Content Rating          0
# Installs_category       0
# dtype: int64

# %% [markdown]
# ## _**Observations set 4:**_
#
# + We have 1695 missing values in `Size_in_bytes` , `Size_in_Kb`, `Size_in_Mb` , which is the 15.6% of the totalvalues in the column
# + There are 1474 missing values in `Rating` , which is the 13.6% of the total values in the column.
# + We have 8 missing values in the `Current Ver`, which is the 0.07% of the total values in the column.
# + We have 2 missing values in the `Android Ver` column, which is 0.01% of the total values in the column.
# + We have only 1 missing value in the `Type`, `Category`, col which is the 0.009% of the total values in the column.

# %%
plt.figure(figsize=(16, 10)) # make figure size  
numeric_cols = ['Rating', 'Reviews', 'Size_in_bytes', 'Installs', 'Price', 'Size_in_Mb'] # make a list of numeric columns
sns.heatmap(df[numeric_cols].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
#
#
# # Fig -6: *Heatmap Of the co-relation between the features of the dataset*

# %%
df[numeric_cols].corr() # this will show the correlation between the numeric columns
# Out:
#                  Rating   Reviews  Size_in_bytes  Installs     Price  \
# Rating         1.000000  0.068147       0.084098  0.051393 -0.021851
# Reviews        0.068147  1.000000       0.238218  0.643123 -0.009666
# Size_in_bytes  0.084098  0.238218       1.000000  0.164794 -0.023000
# Installs       0.051393  0.643123       0.164794  1.000000 -0.011688
# Price         -0.021851 -0.009666      -0.023000 -0.011688  1.000000
# Size_in_Mb     0.084098  0.238218       1.000000  0.164794 -0.023000
#
#                Size_in_Mb
# Rating           0.084098
# Reviews          0.238218
# Size_in_bytes    1.000000
# Installs         0.164794
# Price           -0.023000
# Size_in_Mb       1.000000

# %%
from scipy import stats # import stats from scipy library
df_clean=df.dropna()

# calculate Pearson's R between Rating and Installs
pearson_r, _ = stats.pearsonr(df_clean['Reviews'], df_clean['Installs'])
print(f"Pearson's R between Reviews and Installs: {pearson_r:.4f}")
# Out:
# Pearson's R between Reviews and Installs: 0.6262

# %% [markdown]
# > We will not remove / impute the rating because the rating is correlated with the install attribute i.e we cannot impute the rating if the install atribute is zero. It makes no sense that rating is 4.5 and install does not happen.

# %% [markdown]
# ## _**Observation set 4:**_
#
# + As shown in `Fig-6` The Lighter color shows high co-relation and the darker color shows low co-relation.
# + We can observe that the `Reviews` column is highly corelated with the `Installs` column, which is `0.64` according to the corr(). Which is good
#     - This shows us that reviews and number of installs are directly proportional to each other. So before imputing the reviews we have to take care of number of installs.
# + Installs is slightly correlated with Size_in_Mb or Size_in_bytes , which is 0.16, this also shows us the importance of size and Installs. But we can not depend on it as the Peason correlation is very low.
#
# -----
# Before that lets remove the missing values in the `Current Ver`, `Android Ver`, `Category`, `Type`, `Genres`

# %% [markdown]
# ### _6.0 Removing The Missing Values_

# %%
print(f"Length of dataframe before removving null values: {len(df)}")
# Out:
# Length of dataframe before removving null values: 10841

# %%
# remove the rows having null values in 'Current Ver','Android Ver','Category','Type','Genres' columns
df.dropna(subset=['Current Ver','Android Ver','Category','Type','Genres'],inplace=True)

# %%
print(f"Length of dataframe after removving null values: {len(df)}")
# Out:
# Length of dataframe after removving null values: 10829

# %% [markdown]
# > Total 12 Rows having missing values are removed from the dataset.

# %%
# now lets check again the missing values

df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes        1694
# Size_in_Kb           1694
# Size_in_Mb           1694
# Rating               1469
# Reviews                 0
# Installs                0
# Category                0
# App                     0
# Price                   0
# Type                    0
# Content Rating          0
# Genres                  0
# Current Ver             0
# Last Updated            0
# Android Ver             0
# Installs_category       0
# dtype: int64

# %%
df=df.drop(columns=['Size_in_Kb'])

# %% [markdown]
# # **Obbservation Set 5**:
# + We drop the `Size_in_Kb` because we have already size in bytes and MB also , and there is considered best pratcice to use size in bytes for the size of the file.
#    - We know that we have to take care while dealing with `Rating` column, as it is related `Installs` column.
#    - In Size columns we already know about Varies with device values, which we have converted into null values, we do not need to impute at the moment, as every app has different size and nobody can predict that as nearly as possible.

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_in_bytes', 'Installs',
#        'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'Size_in_Mb', 'Installs_category'],
#       dtype='object')

# %%
# using groupby function to find the trend of Rating with respect to Installs_category
df.groupby('Installs_category')['Rating'].describe()
# Out:
#                      count      mean       std  min  25%  50%  75%  max
# Installs_category
# no                     0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Very low              81.0  4.637037  0.845199  1.0  4.8  5.0  5.0  5.0
# Low                 1278.0  4.170970  0.825605  1.0  3.8  4.4  4.8  5.0
# Moderate            1440.0  4.035417  0.604428  1.4  3.8  4.2  4.5  5.0
# More than moderate  1616.0  4.093255  0.505619  1.6  3.9  4.2  4.5  4.9
# High                2113.0  4.207525  0.376594  1.8  4.0  4.3  4.5  4.9
# Very High           2004.0  4.287076  0.294902  2.0  4.1  4.3  4.5  4.9
# Top Notch            828.0  4.374396  0.193726  3.1  4.3  4.4  4.5  4.8

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(1469)

# %%
# in which Install category the Rating Has NaN values

df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# Low                   880
# Very low              453
# Moderate               88
# More than moderate     31
# no                     14
# High                    3
# Very High               0
# Top Notch               0
# Name: count, dtype: int64

# %%
# plot box plot of Rating in each install category
plt.figure(figsize=(16, 10))
sns.boxplot(x='Installs_category',hue="Installs_category", y='Rating', data=df) # plot boxplot
# Add the text of number of null values in each category
plt.text(0, 3.5, 'Null values: 14')
plt.text(1, 3.5, 'Null values: 874')
plt.text(2, 3.5, 'Null values: 86')
plt.text(3, 3.5, 'Null values: 31')
plt.text(4, 3.5, 'Null values: 3')
plt.text(5, 3.5, 'Null values: 0')
plt.text(6, 3.5, 'Null values: 0')
plt.text(7, 3.5, 'Null values: 0')
# Out:
# Text(7, 3.5, 'Null values: 0')

# %% [markdown]
# **Fig -7:** *Box plot of the missing values of Rating in install Category*

# %% [markdown]
# ## _6.2 Imputing Missing Values_

# %%
# The transform() method allows you to execute a function for each value of the DataFrame.
category_mean=df.groupby('Installs_category')['Rating'].transform('mean') 
df['Rating']=df['Rating'].fillna(category_mean) # fill the missing values in Rating column with the mean of each category

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# no                    14
# Very low               0
# Low                    0
# Moderate               0
# More than moderate     0
# High                   0
# Very High              0
# Top Notch              0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(x='Installs_category',hue="Installs_category", y='Rating', data=df) # plot boxplot
# Add the text of number of null values in each category
plt.text(0, 3.5, 'Null values: 14')
plt.text(1, 3.5, 'Null values: 0')
plt.text(2, 3.5, 'Null values: 0')
plt.text(3, 3.5, 'Null values: 0')
plt.text(4, 3.5, 'Null values: 0')
plt.text(5, 3.5, 'Null values: 0')
plt.text(6, 3.5, 'Null values: 0')
plt.text(7, 3.5, 'Null values: 0')
# Out:
# Text(7, 3.5, 'Null values: 0')

# %% [markdown]
# **Fig -8:** *Box plot of the missing values of Rating in install Category After Imputation*

# %%
# Histogram of percentage of missing values in the dataset after feature engineering
plt.figure(figsize=(16, 6))
# plot null values by their percentage in each column
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of missing values in each column after filling missing values in Rating column')
# Out:
# Text(0.5, 1.0, 'Percentage of missing values in each column after filling missing values in Rating column')

# %% [markdown]
# **Fig -9:** *Histogram of Percentage of the  missing values of Rating in install Category After Imputation*

# %%
#Let's check if there is any similar link with Reviews as well
df['Installs_category'].loc[df['Reviews'].isnull()].value_counts()
# Out:
# Installs_category
# no                    0
# Very low              0
# Low                   0
# Moderate              0
# More than moderate    0
# High                  0
# Very High             0
# Top Notch             0
# Name: count, dtype: int64

# %% [markdown]
# ## _**Observations set 6:**_
#
# + We can observe that all Nan values of `Rating` column is imputed in `Install_Category` column expect `no`.
#   - Because in `no` it is obvious that if app installation is zero there will be no rating so we are good to go.
#   - As seen in `Fig-8` & `Fig-9` of box plot and Histogram , we can see that `no` has a very low count of ratings which is 1
# + We can see that there is no missing values in the `Install Category` the `Review` as has Nan values

# %%
# let's plot the same plots for Reviews column as well
plt.figure(figsize=(16, 6)) # make figure size
sns.boxplot(x='Installs_category', y= 'Reviews', data=df) # plot the boxplot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %% [markdown]
# **Fig -10:** *Box plot of the missing values of Reviews in install Category*

# %% [markdown]
# As we can see that the data is really imbalance it is showing reviews in power of log scale (Approx. 8 million Reviews ). So we need to transform the data to make it more balanced. We can use the following

# %% [markdown]
# > We will Normalize the data using np.log10 () function to reduce the magnitude of the data and to make it easier to work with.

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x='Installs_category',hue="Installs_category", y=np.log10(df['Reviews']), data=df) # plot boxplot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %% [markdown]
# **Fig -11:** *Box plot of the missing values of Reviews in install Category after Normalizing it*

# %%
# Draw a scatter plot between Rating, Reviews and Installs
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Rating', y='Reviews', hue='Installs_category', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %% [markdown]
# **Fig -12:** *Scatter plot of the Rating & Reviews*

# %% [markdown]
# + It doesn't show any trend, because, you should know that Rating is a categorical variable (Ordinal) and Reviews is a continuous variable, therefore, we can not plot them together. Review is continous becauase there is no ranking there , there is large numerical value while rating is categorical. because there is ranking we know that rating can go upto max 5. and there is a ranking like 4.1 ,4.2,4.3 etc. upto 5.0 which is highest.
# + Let's try with Reviews and Installs

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x='Reviews',y='Installs',data=df)
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %% [markdown]
# **Fig -13:** *Scatter plot of the Rating & Reviews*

# %% [markdown]
# We did not see any trend and the issue is we need to normalize the data before plotting it, let's try with log transformation

# %%
# plot reviews and installs in a scatter plot
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x=np.log10(df['Reviews']), y=np.log10(df['Installs']), data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %% [markdown]
# **Fig -14:** *Scatter plot of the Rating & Reviews after Normalization*

# %%
# plot reviews and installs in a scatter plot with trend line
plt.figure(figsize=(16, 6)) # make figure size
sns.lmplot(x='Reviews', y='Installs', data=df) # plot the scatter plot with trend line

# %% [markdown]
# **Fig -15:** *Scatter plot of between Reviews and Installs*

# %% [markdown]
# # **Observation set 7**:
# + We can observe the trend between `Reviews` & `Installs` that the more reviews a product has, the more installs it gets.

# %% [markdown]
# ## 6.3 Removing Duplicates
#
# + Removing the Duplicates is one of the important setp in `wrangling`  Data, we should remove the duplictes in order to get correct data insights.
# + It is also important for model accuracy.

# %%
print(f"The total number of duplicate rows in the dataset are: {df.duplicated().sum()}")
# Out:
# The total number of duplicate rows in the dataset are: 483

# %%
# finding duplicates in the `App` col


print(f"The total number of duplicate rows in App col are: {df['App'].duplicated().sum()}")
# Out:
# The total number of duplicate rows in App col are: 1181

# %% [markdown]
# we have 1181 duplicates in the App col

# %%
# lets check duplicates in each col

for col in df.columns:
    print(f"The total number of duplicate rows in {col} col are: {df[col].duplicated().sum()}")
# Out:
# The total number of duplicate rows in App col are: 1181
# The total number of duplicate rows in Category col are: 10796
# The total number of duplicate rows in Rating col are: 10784
# The total number of duplicate rows in Reviews col are: 4830
# The total number of duplicate rows in Size_in_bytes col are: 10373
# The total number of duplicate rows in Installs col are: 10809
# The total number of duplicate rows in Type col are: 10827
# The total number of duplicate rows in Price col are: 10737
# The total number of duplicate rows in Content Rating col are: 10823
# The total number of duplicate rows in Genres col are: 10710
# The total number of duplicate rows in Last Updated col are: 9453
# The total number of duplicate rows in Current Ver col are: 8046
# The total number of duplicate rows in Android Ver col are: 10796
# The total number of duplicate rows in Size_in_Mb col are: 10373
# The total number of duplicate rows in Installs_category col are: 10821

# %%
# find exact duplicates and print them
df[df['App'].duplicated(keep=False)].sort_values(by='App')
# Out:
#                                                      App             Category  \
# 1393                               10 Best Foods for You   HEALTH_AND_FITNESS
# 1407                               10 Best Foods for You   HEALTH_AND_FITNESS
# 2543                          1800 Contacts - Lens Store              MEDICAL
# 2322                          1800 Contacts - Lens Store              MEDICAL
# 2385                          2017 EMRA Antibiotic Guide              MEDICAL
# 2256                          2017 EMRA Antibiotic Guide              MEDICAL
# 1337                        21-Day Meditation Experience   HEALTH_AND_FITNESS
# 1434                        21-Day Meditation Experience   HEALTH_AND_FITNESS
# 3083                             365Scores - Live Scores               SPORTS
# 5415                             365Scores - Live Scores               SPORTS
# 7035                              420 BZ Budeze Delivery              MEDICAL
# ...

# %%
# remove duplicates

df.drop_duplicates(inplace=True)

# %%
# print number of rows & columns after removing duplicates
print(f"Number of rows after removing duplicates: {df.shape[0]}")
print(f"Number of columns after removing duplicates: {df.shape[1]}")
# Out:
# Number of rows after removing duplicates: 10346
# Number of columns after removing duplicates: 15

# %% [markdown]
# Now after removing 483 duplicate values we have 10346 rows left

# %% [markdown]
# ## MileStone Achived
#
# + We remove the duplicate rows in the dataset by using the `drop_duplicates()` function from pandas library.
# + By this , we ensure that each row in the dataset is unique and there are no duplicate rows.

# %% [markdown]
# ## 6.4 Question & Answer

# %% [markdown]
# ## 6.4.1 Which Category has the highest number of apps

# %%
df['Category'].value_counts().head(10)
# Out:
# Category
# FAMILY             1939
# GAME               1121
# TOOLS               841
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     386
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %% [markdown]
# ## 6.4.2 Which Category has the highest number of installs

# %%
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452271905
# FAMILY                10041632405
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: Installs, dtype: int64

# %% [markdown]
# ## 6.4.3 Which category has the highest number of Reviews

# %%
df.groupby('Category')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME               1415536650
# COMMUNICATION       601273552
# SOCIAL              533576829
# FAMILY              396771746
# TOOLS               273181033
# PHOTOGRAPHY         204297410
# VIDEO_PLAYERS       110380188
# PRODUCTIVITY        102554498
# SHOPPING             94931162
# PERSONALIZATION      75192744
# Name: Reviews, dtype: int64

# %% [markdown]
# ## 6.4.4 Which Category has the highest number of mean Rating

# %%
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# EVENTS                 4.394346
# EDUCATION              4.373794
# ART_AND_DESIGN         4.367122
# BOOKS_AND_REFERENCE    4.358435
# PERSONALIZATION        4.333325
# GAME                   4.281926
# HEALTH_AND_FITNESS     4.273890
# SOCIAL                 4.260441
# PARENTING              4.259759
# SHOPPING               4.253376
# Name: Rating, dtype: float64

# %%
# Plot the Rating distribution
# plot the rating distribution
plt.figure(figsize=(16, 6)) # make figure size
sns.kdeplot(df['Rating'], color="blue", shade=True) # plot the distribution plot
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes  Installs  Type  Price Content Rating  \
# 0      159     19922944.0     10000  Free    0.0       Everyone
# 1      967     14680064.0    500000  Free    0.0       Everyone
# 2    87510      9122611.2   5000000  Free    0.0       Everyone
# 3   215644     26214400.0  50000000  Free    0.0           Teen
# 4      967      2936012.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df.groupby('Content Rating')[['Category','Price','Installs']].value_counts()
# Out:
# Content Rating   Category             Price   Installs
# Adults only 18+  COMICS               0.00    500000          2
#                  SPORTS               0.00    1000000         1
# Everyone         FAMILY               0.00    1000000       193
#                                               100000        176
#                                               10000         166
#                                               1000          157
#                                               10000000      116
#                  GAME                 0.00    10000000      106
#                  TOOLS                0.00    1000000       100
#                                               100000         95
#                  GAME                 0.00    100000000      87
#                  FAMILY               0.00    5000           86
#                  TOOLS                0.00    10000000       86
#                                               10000          82
# ...
